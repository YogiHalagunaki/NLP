# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/yogi/Desktop/Python_Code/venv/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: click in /home/yogi/Desktop/Python_Code/venv/lib/python3.12/site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /home/yogi/Desktop/Python_Code/venv/lib/python3.12/site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/yogi/Desktop/Python_Code/venv/lib/python3.12/site-packages (from nltk) (2025.7.34)
# Requirement already satisfied: tqdm in /home/yogi/Desktop/Python_Code/venv/lib/python3.12/site-packages (from nltk) (4.67.1)

# %%
corpus="""Hello Welcome,to Yogi Halagunaki NLP Examples.
Please do checkout the entire code base in my git to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome,to Yogi Halagunaki NLP Examples.
# Please do checkout the entire code base in my git to become expert in NLP.

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/yogi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to /home/yogi/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome,to Yogi Halagunaki NLP Examples.
# Please do checkout the entire code base in my git to become expert in NLP.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Yogi',
#  'Halagunaki',
#  'NLP',
#  'Examples',
#  '.',
#  'Please',
#  'do',
#  'checkout',
#  'the',
#  'entire',
#  'code',
#  'base',
#  'in',
#  'my',
#  'git',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Yogi', 'Halagunaki', 'NLP', 'Examples', '.']
# ['Please', 'do', 'checkout', 'the', 'entire', 'code', 'base', 'in', 'my', 'git', 'to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Yogi',
#  'Halagunaki',
#  'NLP',
#  'Examples',
#  '.',
#  'Please',
#  'do',
#  'checkout',
#  'the',
#  'entire',
#  'code',
#  'base',
#  'in',
#  'my',
#  'git',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Yogi',
#  'Halagunaki',
#  'NLP',
#  'Examples.',
#  'Please',
#  'do',
#  'checkout',
#  'the',
#  'entire',
#  'code',
#  'base',
#  'in',
#  'my',
#  'git',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
