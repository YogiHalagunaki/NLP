# %%
# !pip install nltk
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 168.2 kB/s eta 0:00:00 0:00:01
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 2.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.9/801.9 kB 1.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 1.5 MB/s eta 0:00:0000:0100:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/yogi/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.data.path.append('/home/yogi/nltk_data')

# %%
corpus = """my name is yogi! and i am data scientist.
i love lerning new things."""

corpus
# Out:
# 'my name is yogi! and i am data scientist.\ni love lerning new things.'

# %%
import nltk
nltk.data.path.append('/home/yogi/nltk_data')

try:
    nltk.data.find('tokenizers/punkt')
    print("Punkt tokenizer found!")
except LookupError:
    print("Punkt tokenizer NOT found! Please check your nltk_data path and files.")
# Out:
# Punkt tokenizer found!

# %%
import nltk
nltk.data.path.append('/home/yogi/nltk_data')

from nltk.tokenize import sent_tokenize

corpus = "Your text here."
sentences = sent_tokenize(corpus)
print(sentences)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[34], line 7
#       4 from nltk.tokenize import sent_tokenize
#       6 corpus = "Your text here."
# ----> 7 sentences = sent_tokenize(corpus)
#       8 print(sentences)
#
# File ~/Desktop/Python_Code/venv/lib/python3.12/site-packages/nltk/tokenize/__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File ~/Desktop/Python_Code/venv/lib/python3.12/site-packages/nltk/tokenize/__init__.py:105, in _get_punkt_tokenizer(language)
# ...
